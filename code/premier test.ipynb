# %% [markdown]
# # Premiers tests de découverte du modèle et d'un algorithme existant.

# %%
import pandas as pd
for i in range (10) :
    dataset1 = pd.read_csv('2013-2014.csv').append()

# %%
# Out:
# <AxesSubplot: >
